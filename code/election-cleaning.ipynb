# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import dataset

# %%
df = pd.read_csv('Loksabha_1962-2019 .csv')

# %%
df.head()
# Out:
#       Pc_name   no type                        state  \
# 0    Adilabad   36  GEN               Andhra Pradesh
# 1       Adoni   27  GEN               Andhra Pradesh
# 2        Agra  433  GEN  Uttar Pradesh [1947 - 1999]
# 3   Ahmedabad  120  GEN                      Gujarat
# 4  Ahmednagar  245  GEN                  Maharashtra
#
#                candidate_name                             party  electors  \
# 0            G. Narayan Reddy          Indian National Congress  4,04,283
# 1  Pendekanti Venkatasubbaiah          Indian National Congress  4,19,077
# 2            Seth Achal Singh          Indian National Congress  4,33,164
# 3   Indulal Kanaiyalal Yagnik  Nutan Maha Gujarat Janta Parisha  4,33,392
# 4   Motilal Kundanmal Firodya          Indian National Congress  4,03,913
#
#       votes Turnout  margin margin%    year
# 0  2,20,383  54.5 %  89,085  40.40%  1962.0
# 1  2,52,379  60.2 %  33,022  13.10%  1962.0
# 2  2,75,663  63.6 %  54,351  19.70%  1962.0
# ...

# %% [markdown]
# # Reviewing Dataset

# %%
df.shape
# Out:
# (8047, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8047 entries, 0 to 8046
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Pc_name         8047 non-null   object
#  1   no              8047 non-null   object
#  2   type            8015 non-null   object
#  3   state           8047 non-null   object
#  4   candidate_name  8047 non-null   object
#  5   party           8047 non-null   object
#  6   electors        8047 non-null   object
#  7   votes           8047 non-null   object
#  8   Turnout         8033 non-null   object
#  9   margin          8047 non-null   object
#  10  margin%         8032 non-null   object
#  11  year            8046 non-null   float64
# dtypes: float64(1), object(11)
# memory usage: 754.5+ KB

# %%
df['year'].unique()
# Out:
# array([1962., 1967., 1971., 1977., 1980., 1984.,   nan, 1989., 1991.,
#        1996., 1998., 1999., 2004., 2009., 2014., 2019.])

# %% [markdown]
# # Analyzing Null values

# %%
df.isnull().sum()
# Out:
# Pc_name            0
# no                 0
# type              32
# state              0
# candidate_name     0
# party              0
# electors           0
# votes              0
# Turnout           14
# margin             0
# margin%           15
# year               1
# dtype: int64

# %%
df[df['year'].isnull()]
# Out:
#      Pc_name    no   type              state candidate_name     party  \
# 3161      No  Type  State  Winning Candidate          Party  Electors
#
#      electors    votes Turnout    margin margin%  year
# 3161    Votes  Turnout  Margin  Margin %     NaN   NaN

# %%
df.drop(labels=3161,inplace=True)

# %%
df[df['year'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Pc_name, no, type, state, candidate_name, party, electors, votes, Turnout, margin, margin%, year]
# Index: []

# %%
df.isnull().sum()
# Out:
# Pc_name            0
# no                 0
# type              32
# state              0
# candidate_name     0
# party              0
# electors           0
# votes              0
# Turnout           14
# margin             0
# margin%           14
# year               0
# dtype: int64

# %%
df[df['type'].isnull()]
# Out:
#             Pc_name  no type                          state  \
# 7521     Amalapuram   7  NaN  Andhra Pradesh [2014 Onwards]
# 7529     Anakapalli   5  NaN  Andhra Pradesh [2014 Onwards]
# 7532      Anantapur  19  NaN  Andhra Pradesh [2014 Onwards]
# 7533       Anantnag   3  NaN                Jammu & Kashmir
# 7541          Aruku   1  NaN  Andhra Pradesh [2014 Onwards]
# 7571        Bapatla  15  NaN  Andhra Pradesh [2014 Onwards]
# 7574      Baramulla   1  NaN                Jammu & Kashmir
# 7637       Chittoor  25  NaN  Andhra Pradesh [2014 Onwards]
# 7672          Eluru  10  NaN  Andhra Pradesh [2014 Onwards]
# 7704         Guntur  13  NaN  Andhra Pradesh [2014 Onwards]
# 7718       Hindupur  20  NaN  Andhra Pradesh [2014 Onwards]
# 7742          Jammu   6  NaN                Jammu & Kashmir
# 7759         Kadapa  21  NaN  Andhra Pradesh [2014 Onwards]
# 7762       Kakinada   6  NaN  Andhra Pradesh [2014 Onwards]
# 7811        Kurnool  18  NaN  Andhra Pradesh [2014 Onwards]
# ...

# %%
df['type'].value_counts()
# Out:
# GEN     6124
# SC      1241
# ST       647
# GENP       2
# Name: type, dtype: int64

# %%
df['type'].fillna('GEN',inplace=True)

# %%
df[df['type'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Pc_name, no, type, state, candidate_name, party, electors, votes, Turnout, margin, margin%, year]
# Index: []

# %%
df[df['Turnout'].isnull()]
# Out:
#                 Pc_name   no type                                    state  \
# 22                Angul  307  GEN                                   Orissa
# 454      Tehri Garhawal  360  GEN              Uttar Pradesh [1947 - 1999]
# 464         Tiruchendur  224  GEN                                   Madras
# 518            Anantnag  144  GEN                          Jammu & Kashmir
# 780           Kokrajhar   46   ST                                    Assam
# 796              Ladakh  145  GEN                          Jammu & Kashmir
# 854            Nagaland  296  GEN                                 Nagaland
# 1007         Vijayawada   13  GEN                           Andhra Pradesh
# 1314  L M And A Islands  513  GEN  Laccadive, Minicoy And Amindivi Islands
# 1564     Arunachal West    1  GEN                        Arunachal Pradesh
# 2014             Sikkim    1  GEN                                   Sikkim
# ...

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Pc_name           0
# no                0
# type              0
# state             0
# candidate_name    0
# party             0
# electors          0
# votes             0
# Turnout           0
# margin            0
# margin%           0
# year              0
# dtype: int64

# %%
df.shape
# Out:
# (8032, 12)

# %% [markdown]
# # Changing dtypes

# %%
df.dtypes
# Out:
# Pc_name            object
# no                 object
# type               object
# state              object
# candidate_name     object
# party              object
# electors           object
# votes              object
# Turnout            object
# margin             object
# margin%            object
# year              float64
# dtype: object

# %%
df.head()
# Out:
#       Pc_name   no type                        state  \
# 0    Adilabad   36  GEN               Andhra Pradesh
# 1       Adoni   27  GEN               Andhra Pradesh
# 2        Agra  433  GEN  Uttar Pradesh [1947 - 1999]
# 3   Ahmedabad  120  GEN                      Gujarat
# 4  Ahmednagar  245  GEN                  Maharashtra
#
#                candidate_name                             party  electors  \
# 0            G. Narayan Reddy          Indian National Congress  4,04,283
# 1  Pendekanti Venkatasubbaiah          Indian National Congress  4,19,077
# 2            Seth Achal Singh          Indian National Congress  4,33,164
# 3   Indulal Kanaiyalal Yagnik  Nutan Maha Gujarat Janta Parisha  4,33,392
# 4   Motilal Kundanmal Firodya          Indian National Congress  4,03,913
#
#       votes Turnout  margin margin%    year
# 0  2,20,383  54.5 %  89,085  40.40%  1962.0
# 1  2,52,379  60.2 %  33,022  13.10%  1962.0
# 2  2,75,663  63.6 %  54,351  19.70%  1962.0
# ...

# %%
df['no']=pd.to_numeric(df['no'])

# %%
df['electors']=df['electors'].str.replace(',','')
df['votes']=df['votes'].str.replace(',','')
df['margin']=df['margin'].str.replace(',','')

# %%
df['Turnout']=df['Turnout'].str.replace('%','')
df.rename(columns={'Turnout':'Turnout%'},inplace=True)

# %%
df['margin%']=df['margin%'].str.replace('%','')

# %%
df.iloc[1674]
# Out:
# Pc_name                Daman And Diu
# no                                 1
# type                             GEN
# state                    Daman & Diu
# candidate_name    Data Not Available
# party                              -
# electors                           -
# votes                              -
# Turnout%                           -
# margin                             -
# margin%                            -
# year                          1977.0
# Name: 1684, dtype: object

# %%
df[df['electors']=='-']
# Out:
#                   Pc_name  no type                        state  \
# 1684        Daman And Diu   1  GEN                  Daman & Diu
# 2112  Autonomous District   3   ST                        Assam
# 2142              Barpeta   6  GEN                        Assam
# 2227        Daman And Diu   1  GEN                  Daman & Diu
# 2243               Dhubri   4  GEN                        Assam
# 2246            Dibrugarh  13  GEN                        Assam
# 2269              Gauhati   7  GEN                        Assam
# 2333               Jorhat  12  GEN                        Assam
# 2342             Kaliabor  11  GEN                        Assam
# 2373            Kokrajhar   5   ST                        Assam
# 2388            Lakhimpur  14  GEN                        Assam
# 2416            Mangaldoi   8  GEN                        Assam
# 2465              Nowgong  10  GEN                        Assam
# 2552             Shillong   1   ST                    Meghalaya
# ...

# %%
df=df[df['electors']!='-']

# %%
df['electors']=pd.to_numeric(df['electors'])
df['votes']=pd.to_numeric(df['votes'])
df['Turnout%']=pd.to_numeric(df['Turnout%'])
df['margin%']=pd.to_numeric(df['margin%'])

# %%
df.dtypes
# Out:
# Pc_name            object
# no                  int64
# type               object
# state              object
# candidate_name     object
# party              object
# electors            int64
# votes               int64
# Turnout%          float64
# margin             object
# margin%           float64
# year              float64
# dtype: object

# %%
df['year']=(df['year']).astype(int)

# %%
df.dtypes
# Out:
# Pc_name            object
# no                  int64
# type               object
# state              object
# candidate_name     object
# party              object
# electors            int64
# votes               int64
# Turnout%          float64
# margin             object
# margin%           float64
# year                int32
# dtype: object

# %%
df.head()
# Out:
#       Pc_name   no type                        state  \
# 0    Adilabad   36  GEN               Andhra Pradesh
# 1       Adoni   27  GEN               Andhra Pradesh
# 2        Agra  433  GEN  Uttar Pradesh [1947 - 1999]
# 3   Ahmedabad  120  GEN                      Gujarat
# 4  Ahmednagar  245  GEN                  Maharashtra
#
#                candidate_name                             party  electors  \
# 0            G. Narayan Reddy          Indian National Congress    404283
# 1  Pendekanti Venkatasubbaiah          Indian National Congress    419077
# 2            Seth Achal Singh          Indian National Congress    433164
# 3   Indulal Kanaiyalal Yagnik  Nutan Maha Gujarat Janta Parisha    433392
# 4   Motilal Kundanmal Firodya          Indian National Congress    403913
#
#     votes  Turnout% margin  margin%  year
# 0  220383      54.5  89085     40.4  1962
# 1  252379      60.2  33022     13.1  1962
# 2  275663      63.6  54351     19.7  1962
# ...

# %%
df.to_csv('election.csv')
