# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import dataset

# %%
df = pd.read_csv('election.csv')

# %%
df.head()
# Out:
#    Unnamed: 0     Pc_name   no type                        state  \
# 0           0    Adilabad   36  GEN               Andhra Pradesh
# 1           1       Adoni   27  GEN               Andhra Pradesh
# 2           2        Agra  433  GEN  Uttar Pradesh [1947 - 1999]
# 3           3   Ahmedabad  120  GEN                      Gujarat
# 4           4  Ahmednagar  245  GEN                  Maharashtra
#
#                candidate_name                             party  electors  \
# 0            G. Narayan Reddy          Indian National Congress    404283
# 1  Pendekanti Venkatasubbaiah          Indian National Congress    419077
# 2            Seth Achal Singh          Indian National Congress    433164
# 3   Indulal Kanaiyalal Yagnik  Nutan Maha Gujarat Janta Parisha    433392
# 4   Motilal Kundanmal Firodya          Indian National Congress    403913
#
#     votes  Turnout%  margin  margin%  year
# 0  220383      54.5   89085     40.4  1962
# ...

# %%
del df['Unnamed: 0']

# %%
df.head()
# Out:
#       Pc_name   no type                        state  \
# 0    Adilabad   36  GEN               Andhra Pradesh
# 1       Adoni   27  GEN               Andhra Pradesh
# 2        Agra  433  GEN  Uttar Pradesh [1947 - 1999]
# 3   Ahmedabad  120  GEN                      Gujarat
# 4  Ahmednagar  245  GEN                  Maharashtra
#
#                candidate_name                             party  electors  \
# 0            G. Narayan Reddy          Indian National Congress    404283
# 1  Pendekanti Venkatasubbaiah          Indian National Congress    419077
# 2            Seth Achal Singh          Indian National Congress    433164
# 3   Indulal Kanaiyalal Yagnik  Nutan Maha Gujarat Janta Parisha    433392
# 4   Motilal Kundanmal Firodya          Indian National Congress    403913
#
#     votes  Turnout%  margin  margin%  year
# 0  220383      54.5   89085     40.4  1962
# 1  252379      60.2   33022     13.1  1962
# 2  275663      63.6   54351     19.7  1962
# ...

# %% [markdown]
# # Analyzing

# %% [markdown]
# ## Analyzing according to 2019

# %%
df_19=df[df['year']==2019]
df_19
# Out:
#              Pc_name  no type                         state  \
# 7452        Adilabad   1   ST                     Telangana
# 7453            Agra  18   SC  Uttar Pradesh [2000 Onwards]
# 7454      Ahmadnagar  37  GEN                   Maharashtra
# 7455  Ahmedabad East   7  GEN                       Gujarat
# 7456  Ahmedabad West   8   SC                       Gujarat
# ...              ...  ..  ...                           ...
# 7988          Wardha   8  GEN                   Maharashtra
# 7989         Wayanad   4  GEN                        Kerala
# 7990      West Delhi   6  GEN          Delhi [1977 Onwards]
# 7991  Yavatmal-Washi  14  GEN                   Maharashtra
# 7992       Zahirabad   5  GEN                     Telangana
#
#                          candidate_name                      party  electors  \
# 7452                     Soyam Bapu Rao      Bharatiya Janta Party   1382837
# 7453              Satyapal Singh Baghel      Bharatiya Janta Party   1866262
# ...

# %%
df_19.shape
# Out:
# (541, 12)

# %%
df_19['state'] = df_19['state'].replace('Uttar Pradesh [2000 Onwards]','Uttar Pradesh')
df_19['state'] = df_19['state'].replace('Andhra Pradesh [2014 Onwards]','Andhra Pradesh')
# Out:
# C:\Users\shukl\AppData\Local\Temp\ipykernel_2692\4276843113.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_19['state'] = df_19['state'].replace('Uttar Pradesh [2000 Onwards]','Uttar Pradesh')
# C:\Users\shukl\AppData\Local\Temp\ipykernel_2692\4276843113.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_19['state'] = df_19['state'].replace('Andhra Pradesh [2014 Onwards]','Andhra Pradesh')

# %% [markdown]
# # total Seats by party

# %%
df_19['party'].value_counts()
# Out:
# Bharatiya Janta Party                       302
# Indian National Congress                     52
# Dravida Munetra Kazhagam                     23
# Yuvajana Sramika Rythu Congress Party        22
# All India Trinamool Congress                 22
# Shiv Sena                                    18
# Janata Dal (United)                          16
# Biju Janata Dal                              12
# Bahujan Samaj Party                          10
# Telangana Rashtra Samithi                     9
# Lok Jan Shakti Party                          6
# Samajwadi Party                               5
# Nationalist Congress Party                    5
# Independent                                   4
# Jammu & Kashmir National Conference           3
# Telugu Desam                                  3
# Indian Union Muslim League                    3
# Communist Party Of India (Marxist)            3
# Apna Dal (Soneylal)                           2
# Shiromani Akali Dal                           2
# ...

# %%
df_19.head()
# Out:
#              Pc_name  no type          state  \
# 7452        Adilabad   1   ST      Telangana
# 7453            Agra  18   SC  Uttar Pradesh
# 7454      Ahmadnagar  37  GEN    Maharashtra
# 7455  Ahmedabad East   7  GEN        Gujarat
# 7456  Ahmedabad West   8   SC        Gujarat
#
#                          candidate_name                  party  electors  \
# 7452                     Soyam Bapu Rao  Bharatiya Janta Party   1382837
# 7453              Satyapal Singh Baghel  Bharatiya Janta Party   1866262
# 7454  Dr. Sujay Radhakrishna Vikhepatil  Bharatiya Janta Party   1793677
# 7455         Patel Hasmukhbhai Somabhai  Bharatiya Janta Party   1713598
# 7456               Dr. Kirit P. Solanki  Bharatiya Janta Party   1580673
#
#         votes  Turnout%  margin  margin%  year
# 7452  1063730      77.9   58560      5.5  2019
# 7453  1145323      61.7  211546     18.5  2019
# 7454  1203797      67.3  281474     23.4  2019
# 7455  1116367      65.7  434330     38.9  2019
# ...

# %%
df_19['state'].value_counts()
# Out:
# Uttar Pradesh                    80
# Maharashtra                      48
# West Bengal                      42
# Bihar [2000 Onwards]             40
# Tamil Nadu                       38
# Madhya Pradesh [2000 Onwards]    29
# Karnataka                        28
# Gujarat                          26
# Rajasthan                        25
# Andhra Pradesh                   25
# Orissa                           21
# Kerala                           20
# Telangana                        17
# Jharkhand                        14
# Punjab                           13
# Assam                            13
# Chhattisgarh                     11
# Haryana                          10
# Delhi [1977 Onwards]              7
# Jammu & Kashmir                   6
# Uttarakhand                       5
# Himachal Pradesh                  4
# Tripura                           2
# Meghalaya                         2
# Manipur                           2
# Goa                               2
# ...

# %% [markdown]
# # Q1. Seat with the highest voters

# %% [markdown]
# # Q2. Seats with the lowest voters

# %% [markdown]
# # Q3. Winner with the biggest margin

# %% [markdown]
# # Q4. Winner with the smallest margin

# %% [markdown]
# # Q5. Seat with the higest turnout

# %% [markdown]
# # Q6. Seat with the lowest turnout

# %% [markdown]
# # Q7. Analysis of Seats other than GEN seats

# %% [markdown]
# # Q8. percentage of votes to each party

# %% [markdown]
# # Q9. total electors in india and total votes casted

# %% [markdown]
# # Q10. average turnout

# %% [markdown]
# # Q11. average turnout statewise

# %% [markdown]
# # Constituency with highest turnout

# %%
df_19.to_csv('elections_2019.csv')
